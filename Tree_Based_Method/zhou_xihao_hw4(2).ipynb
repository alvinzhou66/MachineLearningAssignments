# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # b(1). Read data and fix the missing value

# %%
training_set = pd.read_csv('data/aps_failure_training_set.csv', skiprows=20)
test_set = pd.read_csv('data/aps_failure_test_set.csv', skiprows=20)
training_set = training_set.replace("na", "NaN")
test_set = test_set.replace("na","NaN")

# %%
x_training = training_set.drop('class', axis=1)
x_test = test_set.drop('class', axis=1)
y_training = training_set['class']
y_test = test_set['class']
mean_set = Imputer(missing_values="NaN", axis=1)
x_training = pd.DataFrame(mean_set.fit_transform(x_training), columns=x_training.columns)
x_training
# Out:
#          aa_000        ab_000        ac_000        ad_000  ae_000  af_000  \
# 0       76698.0  1.377036e+07  2.130706e+09  2.800000e+02     0.0     0.0
# 1       33058.0  4.461603e+05  0.000000e+00  4.461603e+05     0.0     0.0
# 2       41040.0  3.225849e+05  2.280000e+02  1.000000e+02     0.0     0.0
# 3          12.0  0.000000e+00  7.000000e+01  6.600000e+01     0.0    10.0
# 4       60874.0  6.269397e+05  1.368000e+03  4.580000e+02     0.0     0.0
# 5       38312.0  1.354696e+07  2.130706e+09  2.180000e+02     0.0     0.0
# 6          14.0  0.000000e+00  6.000000e+00  9.431018e+03     0.0     0.0
# 7      102960.0  1.377775e+07  2.130706e+09  1.160000e+02     0.0     0.0
# 8       78696.0  9.551237e+05  0.000000e+00  9.551237e+05     0.0     0.0
# 9      153204.0  0.000000e+00  1.820000e+02  6.336441e+05     0.0     0.0
# 10      39196.0  3.560546e+05  2.040000e+02  1.700000e+02     0.0     0.0
# 11      45912.0  4.120016e+05  0.000000e+00  4.540000e+02     0.0     0.0
# 12       2104.0  3.439601e+04  3.600000e+01  2.600000e+01     0.0     0.0
# 13     118950.0  1.545870e+06  1.390000e+03  1.298000e+03     0.0     0.0
# 14      24416.0  2.690418e+05  0.000000e+00  2.690418e+05     0.0     0.0
# 15         14.0  0.000000e+00  6.200000e+01  3.400000e+01     0.0     0.0
# 16      31300.0  0.000000e+00  7.840000e+02  7.400000e+02     0.0     0.0
# 17        736.0  2.000000e+00  2.400000e+01  2.200000e+01    16.0    20.0
# 18        332.0  1.333083e+07  2.130706e+09  2.000000e+01     0.0     0.0
# 19       1432.0  1.334242e+07  2.130706e+09  8.200000e+01     0.0     0.0
# 20      41212.0  0.000000e+00  2.130706e+09  1.040000e+02   104.0   172.0
# 21         14.0  8.602389e+03  6.000000e+00  6.000000e+00     0.0     0.0
# 22     157128.0  1.434028e+07  2.130706e+09  4.240000e+02     0.0     0.0
# 23     453236.0  8.788944e+06  2.926000e+03  8.788944e+06     0.0     0.0
# 24      58246.0  1.378208e+07  2.130706e+09  2.416000e+03     0.0     0.0
# 25      29394.0  4.821387e+05  0.000000e+00  4.821387e+05     0.0     0.0
# 26       8690.0  1.044945e+05  4.760000e+02  3.640000e+02     0.0     0.0
# 15989  0.000000e+00
# 15990  0.000000e+00
# 15991  0.000000e+00
# 15992  0.000000e+00
# 15993  0.000000e+00
# 15994  0.000000e+00
# 15995  0.000000e+00
# 15996  0.000000e+00
# 15997  0.000000e+00
# 15998  0.000000e+00
# 15999  0.000000e+00
#
# [16000 rows x 170 columns]

# %% [markdown]
# # b(2). Calculate CV for 170 features

# %%
coefficient_variations = {}

for i in x_training.columns:

    std = np.std(x_training[i])
    mean = np.mean(x_training[i])
    coefficient_variations[i] = std/mean

for key,value in coefficient_variations.items():
    print('{key}:{value}'.format(key = key, value = value))
# Out:
# aa_000:2.4509171533790517
# ab_000:2.179287152741949
# ac_000:2.3086626650850555
# ad_000:64.50775571113346
# ae_000:7.692755166627313
# af_000:7.692518198045193
# ag_000:44.965173375699024
# ag_001:41.64108064518036
# ag_002:24.985320209767423
# ag_003:8.908216114601231
# ag_004:5.429378397470193
# ag_005:2.958712320102778
# ag_006:2.3717151806324446
# ag_007:2.9253923478524295
# ag_008:10.490961782499358
# ag_009:31.6936380888098
# ah_000:2.318367478638948
# ai_000:20.47045716644
# aj_000:28.301499657695675
# ak_000:6.725115105620066
# al_000:9.677733168031576
# am_0:8.981175251348924
# an_000:2.2574733675745295
# ao_000:2.276456875532256
# ap_000:3.077962594534967
# aq_000:2.9585084174298375
# ar_000:7.324073834955462
# as_000:29.895126565756076
# at_000:23.67084628503319
# au_000:29.71624039225499
# av_000:7.63001296724381
# ax_000:7.671143047496919
# ay_000:28.954673626674342
# ay_001:35.25925243740465
# ay_002:29.781236785210698
# ay_003:28.358253183749227
# ay_004:27.78949612455853
# ay_005:12.073549693517414
# ay_006:3.05453485081342
# ay_007:3.312619934458937
# ay_008:3.804911043240516
# ay_009:41.54126005949955
# az_000:24.77100839724786
# az_001:30.707781597897117
# az_002:24.874023574749717
# az_003:8.042646512531896
# az_004:2.8450304892046656
# az_005:3.0358096440442246
# az_006:8.953968349103617
# az_007:18.88444284559582
# az_008:42.51827036097766
# az_009:45.3978818666585
# ba_000:2.7127057675476838
# ba_001:2.650758343840996
# ba_002:3.006447378904346
# ba_003:3.0203442283756905
# ba_004:3.1655538120046365
# ba_005:3.3012302746493813
# ba_006:3.453156447681385
# ba_007:3.4197620039465106
# ba_008:10.65225742062362
# ba_009:11.88219873999336
# bb_000:2.4128612901278856
# bc_000:7.296321992725449
# bd_000:7.278594611868478
# be_000:7.6154212213447146
# bf_000:7.688443761036791
# bg_000:2.316450966012228
# bh_000:6.828917837248709
# bi_000:3.0843349497570616
# bj_000:3.594783279509899
# bk_000:3.1980342925210805
# bl_000:2.9280388368546078
# bm_000:2.4178665674271604
# bn_000:2.274713719184893
# bo_000:2.164890423303937
# bp_000:2.090047269678515
# bq_000:2.0485925685127384
# br_000:2.028019011117737
# bs_000:4.84391499550469
# bt_000:5.139670260856231
# bu_000:2.4132494209214856
# bv_000:2.413249257552032
# bx_000:2.565708763346554
# by_000:13.418934953932055
# bz_000:5.019780659824875
# ca_000:5.76430482533937
# cb_000:1.395883036522379
# cc_000:2.576765230379721
# cd_000:0.3730139697531102
# ce_000:5.254007257195811
# cf_000:64.54336377341325
# cg_000:4.593933124744389
# ch_000:4.5947600626458245
# ci_000:2.406743483380938
# cj_000:11.045765408859825
# ck_000:3.0738518144837794
# cl_000:5.970524459992473
# cm_000:5.894674559635193
# cn_000:37.30650844218073
# cn_001:15.537200244838314
# cn_002:6.794135384402802
# cn_003:4.1924785857176365
# cn_004:2.6330063644837876
# cn_005:2.3623005612943135
# cn_006:3.248781604789704
# cn_007:7.882000300698503
# cn_008:16.04730508870293
# cn_009:29.500543623757327
# co_000:64.51713297350211
# cp_000:7.2959847315460475
# cq_000:2.413249223624044
# cr_000:2.179276563806198
# cs_000:28.745888742328674
# cs_001:42.95102882185185
# cs_002:5.200495158821641
# cs_003:3.261027463634914
# cs_004:4.688914387555009
# cs_005:2.5227594295778526
# cs_006:2.238180780500309
# cs_007:17.68974598480836
# cs_008:45.74377918071877
# cs_009:47.22818785727692
# ct_000:4.847566431594013
# cu_000:4.842396821589898
# cv_000:1.9516085002247092
# cx_000:3.4141340265333526
# cy_000:4.852804433329431
# cz_000:4.688345325816632
# da_000:4.855686406129399
# db_000:4.855620183867947
# dc_000:1.9293787772129531
# dd_000:7.518794524141438
# de_000:7.306086982840759
# df_000:6.7442673081395155
# dg_000:6.695498028692108
# dh_000:7.103920333167944
# di_000:6.058332359110332
# dj_000:6.796806143171007
# dk_000:6.750311692628393
# dl_000:7.4621200437168795
# dm_000:6.6764405862470415
# dn_000:9.68665732284596
# do_000:6.162889560393253
# dp_000:6.998920991111629
# dq_000:21.308047986452706
# dr_000:4.974062283208026
# ds_000:4.654668469735607
# dt_000:6.644562170639333
# du_000:2.8188950454481
# dv_000:3.1786634839326346
# dx_000:4.629011982270276
# dy_000:6.971974275643537
# dz_000:7.32408758077984
# ea_000:7.324021492531431
# eb_000:4.454116176550265
# ec_00:5.643469341996113
# ed_000:5.935675473778656
# ee_000:3.317387655358481
# ee_001:3.29899010577617
# ee_002:2.7070792702752304
# ee_003:3.0959962165999557
# ee_004:2.7323162324491936
# ee_005:2.9726289954744933
# ee_006:3.3593442317850655
# ee_007:5.022521033015331
# ee_008:4.124551738392823
# ee_009:23.78184926332685
# ef_000:7.32357366577933
# eg_000:7.324087727470482

# %% [markdown]
# # b(3). Plot correlation

# %%
f = plt.figure(figsize=(10, 7))
plt.matshow(x_training.corr(), fignum=f.number)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=6)
plt.title('Correlation Matrix for training set', fontsize=16)
# Out:
# Text(0.5,1.05,'Correlation Matrix for training set')

# %% [markdown]
# # b(4). Pick highest CV features

# %%
# sqrt(171) round down = 13
high_cv_features = sorted(coefficient_variations, key=coefficient_variations.get)[-13:]
x_highCV = x_training[high_cv_features]

# %%
sb.pairplot(x_highCV)

# %%
sb.boxplot(x=x_highCV.iloc[:,0])

# %%
sb.boxplot(x=x_highCV.iloc[:,1])

# %%
sb.boxplot(x=x_highCV.iloc[:,2])

# %%
sb.boxplot(x=x_highCV.iloc[:,3])

# %%
sb.boxplot(x=x_highCV.iloc[:,4])

# %%
sb.boxplot(x=x_highCV.iloc[:,5])

# %%
sb.boxplot(x=x_highCV.iloc[:,6])

# %%
sb.boxplot(x=x_highCV.iloc[:,7])

# %%
sb.boxplot(x=x_highCV.iloc[:,8])

# %%
sb.boxplot(x=x_highCV.iloc[:,9])

# %%
sb.boxplot(x=x_highCV.iloc[:,10])

# %%
sb.boxplot(x=x_highCV.iloc[:,11])

# %%
sb.boxplot(x=x_highCV.iloc[:,12])

# %% [markdown]
# # b(5). Determine the number of pos and neg class

# %%
print(training_set['class'].value_counts())
print('                                   ')
print('It is imbalanced')
# Out:
# neg    59000
# pos     1000
# Name: class, dtype: int64
#
# It is imbalanced

# %% [markdown]
# # c. Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
clf = RandomForestClassifier(random_state=0).fit(x_training,y_training)
cm0 = confusion_matrix(y_training, clf.predict(x_training))
print('Training Set Confusion_matrix:')
print('-----------------')
print(cm0)
y_pred = clf.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print('Test Set Confusion_matrix:')
print('-----------------')
print(cm)
# Out:
# Training Set Confusion_matrix:
# -----------------
# [[58996     4]
#  [   40   960]]
# Test Set Confusion_matrix:
# -----------------
# [[15604    21]
#  [  130   245]]

# %%
lb = preprocessing.LabelBinarizer()
y_train = lb.fit_transform(y_training)
y_pred0 = lb.fit_transform(clf.predict(x_training))
fpr, tpr, thresholds = roc_curve(y_train, y_pred0)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='yellow')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Training ROC curve (auc = %0.2f)' % roc_auc)
plt.show()
print('training auc =', roc_auc)
# Out:
# training auc = 0.9799661016949152

# %%
y_test1 = lb.fit_transform(y_test)
y_pred = lb.fit_transform(y_pred)
fpr, tpr, thresholds = roc_curve(y_test1, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='yellow')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test ROC curve (auc = %0.2f)' % roc_auc)
plt.show()
print('test auc =', roc_auc)
# Out:
# test auc = 0.8259946666666665

# %%
from sklearn.metrics import accuracy_score
misclassification_train = 1 - accuracy_score(y_training, clf.predict(x_training))
print('Training missclassification = ', misclassification_train)
misclassification_test = 1 - accuracy_score(y_test, clf.predict(x_test))
print('Test missclassification = ', misclassification_test)
# Out:
# Training missclassification =  0.0007333333333333636
# Test missclassification =  0.009437499999999988

# %%
clf = RandomForestClassifier(random_state=0, oob_score=True).fit(x_training,y_training)
print('out of bag error =', 1-clf.oob_score_)
print('test error =', 1-clf.score(x_test,y_test))
# Out:
# out of bag error = 0.008950000000000014
# test error = 0.009437499999999988

# %% [markdown]
# # d. Handle imbalanced classes in Random Forest

# %%
# use guide from:https://chrisalbon.com/machine_learning/trees_and_forests/handle_imbalanced_classes_in_random_forests/
clf = RandomForestClassifier(random_state=0,class_weight='balanced').fit(x_training,y_training)
cm0 = confusion_matrix(y_training, clf.predict(x_training))
print('Training Set Confusion_matrix:')
print('-----------------')
print(cm0)
y_pred = clf.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print('Test Set Confusion_matrix:')
print('-----------------')
print(cm)
# Out:
# Training Set Confusion_matrix:
# -----------------
# [[58999     1]
#  [   61   939]]
# Test Set Confusion_matrix:
# -----------------
# [[15611    14]
#  [  174   201]]

# %%
lb = preprocessing.LabelBinarizer()
y_train = lb.fit_transform(y_training)
y_pred0 = lb.fit_transform(clf.predict(x_training))
fpr, tpr, thresholds = roc_curve(y_train, y_pred0)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='yellow')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Training ROC curve (auc = %0.2f)' % roc_auc)
plt.show()
print('training auc =', roc_auc)
# Out:
# training auc = 0.969491525423729

# %%
y_test1 = lb.fit_transform(y_test)
y_pred = lb.fit_transform(y_pred)
fpr, tpr, thresholds = roc_curve(y_test1, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='yellow')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test ROC curve (auc = %0.2f)' % roc_auc)
plt.show()
print('test auc =', roc_auc)
# Out:
# test auc = 0.767552

# %%
misclassification_train = 1 - accuracy_score(y_training, clf.predict(x_training))
print('Training missclassification = ', misclassification_train)
misclassification_test = 1 - accuracy_score(y_test, clf.predict(x_test))
print('Test missclassification = ', misclassification_test)
# Out:
# Training missclassification =  0.0010333333333333306
# Test missclassification =  0.011750000000000038

# %%
clf = RandomForestClassifier(random_state=0, class_weight='balanced', oob_score=True).fit(x_training,y_training)
print('out of bag error =', 1-clf.oob_score_)
print('test error =', 1-clf.score(x_test,y_test))
# Out:
# out of bag error = 0.010283333333333311
# test error = 0.011750000000000038

# %% [markdown]
# # e. Call weka to build a decision tree (10-fold CV)

# %%
import weka.core.converters as converters
import weka.core.jvm as jvm

# %%
training_weka = pd.concat([x_training, y_training], axis=1, ignore_index=True)
training_weka.to_csv('training_weka.csv',index=False)
test_weka = pd.concat([x_test, y_test], axis=1, ignore_index=True)
test_weka.to_csv('test_weka.csv', index=False)

# %%
jvm.start()
# Out:
# DEBUG:weka.core.jvm:Adding bundled jars
# DEBUG:weka.core.jvm:Classpath=['c:\\users\\zxh\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\javabridge\\jars\\rhino-1.7R4.jar', 'c:\\users\\zxh\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\javabridge\\jars\\runnablequeue.jar', 'c:\\users\\zxh\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\javabridge\\jars\\cpython.jar', 'c:\\users\\zxh\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\weka\\lib\\python-weka-wrapper.jar', 'c:\\users\\zxh\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\weka\\lib\\weka.jar']
# DEBUG:weka.core.jvm:MaxHeapSize=default
# DEBUG:weka.core.jvm:Package support disabled

# %%
training_set = converters.load_any_file("training_weka.csv")
training_set.class_is_last()
test_set = converters.load_any_file("test_weka.csv")
test_set.class_is_last()

# %%
from weka.classifiers import Classifier
from weka.classifiers import Evaluation
from weka.core.classes import Random
import weka.plot.classifiers as plcls

# %%
clf = Classifier(classname="weka.classifiers.trees.LMT")
evl = Evaluation(training_set)
evl.crossvalidate_model(classifier=clf, data=training_set, num_folds = 10, rnd=Random(42))

# %%
print(evl.confusion_matrix)
print(evl.summary())
print(evl.class_details())
# Out:
# [[58836.   164.]
#  [  334.   666.]]
#
# Correctly Classified Instances       59502               99.17   %
# Incorrectly Classified Instances       498                0.83   %
# Kappa statistic                          0.7237
# Mean absolute error                      0.0115
# Root mean squared error                  0.0817
# Relative absolute error                 35.1622 %
# Root relative squared error             63.8506 %
# Total Number of Instances            60000
#
# === Detailed Accuracy By Class ===
#
#                  TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
#                  0.997    0.334    0.994      0.997    0.996      0.727    0.962     0.998     neg
#                  0.666    0.003    0.802      0.666    0.728      0.727    0.962     0.755     pos
# Weighted Avg.    0.992    0.328    0.991      0.992    0.991      0.727    0.962     0.994

# %%
print('Training ROC')
plcls.plot_roc(evl, class_index=[0, 1], wait=True)
# Out:
# Training ROC

# %%
evl = Evaluation(test_set)
evl.crossvalidate_model(classifier=clf, data=test_set, num_folds = 10, rnd=Random(42))

# %%
print(evl.confusion_matrix)
print(evl.summary())
print(evl.class_details())
# Out:
# [[15555.    70.]
#  [  128.   247.]]
#
# Correctly Classified Instances       15802               98.7625 %
# Incorrectly Classified Instances       198                1.2375 %
# Kappa statistic                          0.7076
# Mean absolute error                      0.0172
# Root mean squared error                  0.0999
# Relative absolute error                 37.5384 %
# Root relative squared error             66.0445 %
# Total Number of Instances            16000
#
# === Detailed Accuracy By Class ===
#
#                  TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
#                  0.996    0.341    0.992      0.996    0.994      0.710    0.975     0.999     neg
#                  0.659    0.004    0.779      0.659    0.714      0.710    0.975     0.750     pos
# Weighted Avg.    0.988    0.333    0.987      0.988    0.987      0.710    0.975     0.993

# %%
print('Training ROC')
plcls.plot_roc(evl, class_index=[0, 1], wait=True)
# Out:
# Training ROC

# %% [markdown]
# # f.SMOTE the data first and then do e again

# %%
# using guide form:https://imbalanced-learn.readthedocs.io/en/stable/generated/imblearn.over_sampling.SMOTE.html
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
x_training_0, y_training_0 = sm.fit_sample(x_training,y_training.replace({0:'neg',1:'pos'})) 
training_smote = pd.concat([pd.DataFrame(x_training_0), pd.DataFrame(y_training_0)], axis=1, ignore_index=True)
training_smote.to_csv('training_smote.csv',index=False)
x_test_0, y_test_0 = sm.fit_sample(x_test,y_test.replace({0:'neg', 1:'pos'}))
test_smote = pd.concat([pd.DataFrame(x_test_0), pd.DataFrame(y_test_0)], axis=1, ignore_index=True)
test_smote.to_csv('test_smote.csv', index=False)
# Out:
# Using TensorFlow backend.

# %%
training_set = converters.load_any_file("training_smote.csv")
training_set.class_is_last()
test_set = converters.load_any_file("test_smote.csv")
test_set.class_is_last()

# %%
clf = Classifier(classname="weka.classifiers.trees.LMT")
evl = Evaluation(training_set)
evl.crossvalidate_model(classifier=clf, data=training_set, num_folds = 10, rnd=Random(42))

# %%
print(evl.confusion_matrix)
print(evl.summary())
print(evl.class_details())
# Out:
# [[57986.  1014.]
#  [ 1111. 57889.]]
#
# Correctly Classified Instances      115875               98.1992 %
# Incorrectly Classified Instances      2125                1.8008 %
# Kappa statistic                          0.964
# Mean absolute error                      0.0303
# Root mean squared error                  0.1226
# Relative absolute error                  6.053  %
# Root relative squared error             24.5227 %
# Total Number of Instances           118000
#
# === Detailed Accuracy By Class ===
#
#                  TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
#                  0.983    0.019    0.981      0.983    0.982      0.964    0.994     0.994     neg
#                  0.981    0.017    0.983      0.981    0.982      0.964    0.994     0.991     pos
# Weighted Avg.    0.982    0.018    0.982      0.982    0.982      0.964    0.994     0.993

# %%
print('Training ROC')
plcls.plot_roc(evl, class_index=[0, 1], wait=True)
# Out:
# Training ROC

# %%
evl = Evaluation(test_set)
evl.crossvalidate_model(classifier=clf, data=test_set, num_folds = 10, rnd=Random(42))

# %%
print(evl.confusion_matrix)
print(evl.summary())
print(evl.class_details())
# Out:
# [[15346.   279.]
#  [  112. 15513.]]
#
# Correctly Classified Instances       30859               98.7488 %
# Incorrectly Classified Instances       391                1.2512 %
# Kappa statistic                          0.975
# Mean absolute error                      0.0211
# Root mean squared error                  0.104
# Relative absolute error                  4.2269 %
# Root relative squared error             20.8094 %
# Total Number of Instances            31250
#
# === Detailed Accuracy By Class ===
#
#                  TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
#                  0.982    0.007    0.993      0.982    0.987      0.975    0.996     0.995     neg
#                  0.993    0.018    0.982      0.993    0.988      0.975    0.996     0.993     pos
# Weighted Avg.    0.987    0.013    0.988      0.987    0.987      0.975    0.996     0.994

# %%
print('Training ROC')
plcls.plot_roc(evl, class_index=[0, 1], wait=True)
# Out:
# Training ROC

# %% [markdown]
#  For the ROC plots above, 2nd and 4th of them should be "Test ROC", I had a print misstake, but rerun the progress cost too much time......

# %% [markdown]
# # ISLR 6.8.3

# %% [markdown]
# a) When the avaliable range of beta increased, the model will be more flexable, as a linear model, when it becomes flexable, RSS will be lower. So we choose (iv)
#
# b) When we test the trained model on the test set, same as training, the RSS will decrease. However, after we find the "best" model, the increase of beta might cause an over-fit to our model. So I expect RSS will first decrease and then increase after the "best" beta was found. Choose (ii)
#
# c) The variance will increase because range of beta increased. Choose (iii)
#
# d) The bias will decrease because variance increased. Choose (iv)
#
# e) Irreducible error will be there no matter what beta we have, so choose (v)

# %% [markdown]
# # ISLR 6.8.5

# %% [markdown]
# ![](6.8.5.jpg)

# %% [markdown]
# # ISLR 8.4.5

# %% [markdown]
# For the mojority vote mothod, we classify X as RED because 6 of the value is larger than 0.5.
#
# For the average probability method, we calssify X as GREEN because the average value is 0.45 which is less then 0.5.

# %% [markdown]
# # ISLR 9.7.3
